# %%
# %load_ext cython

# %%
import pyximport
pyximport.install()

from pyknotid.spacecurves import chelpers
# Out:
# C:\Users\Kolya\.conda\envs\MathProjectKnots\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\Kolya\.conda\envs\MathProjectKnots\lib\site-packages\pyknotid\spacecurves\chelpers.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# ---------------------------------------------------------------------------
# DistutilsExecError                        Traceback (most recent call last)
# ~\.conda\envs\MathProjectKnots\lib\distutils\_msvccompiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     423             try:
# --> 424                 self.spawn(args)
#     425             except DistutilsExecError as msg:
#
# ~\.conda\envs\MathProjectKnots\lib\distutils\_msvccompiler.py in spawn(self, cmd)
#     542             os.environ['path'] = self._paths
# ...

# %%
# %%cython
# from pyknotid.spacecurves import chelpers
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-3bca60c063e8> in <module>
# ----> 1 get_ipython().run_cell_magic('cython', '', 'from pyknotid.spacecurves import chelpers\n')
#
# ~\.conda\envs\MathProjectKnots\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# <C:\Users\Kolya\.conda\envs\MathProjectKnots\lib\site-packages\decorator.py:decorator-gen-129> in cython(self, line, cell)
#
# ~\.conda\envs\MathProjectKnots\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# ...
